# %% [markdown]
# # BIOS512 Assignment #5

# %% [markdown]
# 📈 For this assignment we will work with inflation data provided by the [US Bureah of Labor Statistics](https://www.bls.gov/cpi/tables/). The data is provided as `excel` files. We have the data for years 2019-2023 in our `assignemnts` folder under the filename `revised-seasonally-adjusted-indexes-2023.xlsx`.

# %% [markdown]
# Let's read the data in first. You'll need to load both the `tidyverse` and the `readxl` libraries.

# %%
library('tidyverse')
library('readxl')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# Now you should have a function in your session called `read_excel`. Pass in the filename from above as a `string` to the `read_excel` function and capture the `tibble` output with a variable called `df_price_index`.

# %%
df_price_index = read_excel('revised-seasonally-adjusted-indexes-2023.xlsx')
df_price_index
# Out:
#      ITEM    TITLE                       seriesid
# 1    SA0     All items                   CUSR0000SA0
# 2    SA0     All items                   CUSR0000SA0
# 3    SA0     All items                   CUSR0000SA0
# 4    SA0     All items                   CUSR0000SA0
# 5    SA0     All items                   CUSR0000SA0
# 6    SA0     All items                   CUSR0000SA0
# 7    SA0     All items                   CUSR0000SA0
# 8    SA0     All items                   CUSR0000SA0
# 9    SA0     All items                   CUSR0000SA0
# 10   SA0     All items                   CUSR0000SA0
# 11   SA0     All items                   CUSR0000SA0
# 12   SA0     All items                   CUSR0000SA0
# 13   SA0     All items                   CUSR0000SA0
# 14   SA0     All items                   CUSR0000SA0
# 15   SA0     All items                   CUSR0000SA0
# 16   SA0E    Energy                      CUSR0000SA0E
# 17   SA0E    Energy                      CUSR0000SA0E
# 18   SA0E    Energy                      CUSR0000SA0E
# 19   SA0E    Energy                      CUSR0000SA0E
# 20   SA0E    Energy                      CUSR0000SA0E
# 21   SA0E    Energy                      CUSR0000SA0E
# 22   SA0E    Energy                      CUSR0000SA0E
# 23   SA0E    Energy                      CUSR0000SA0E
# 24   SA0E    Energy                      CUSR0000SA0E
# 25   SA0E    Energy                      CUSR0000SA0E
# 26   SA0E    Energy                      CUSR0000SA0E
# 27   SA0E    Energy                      CUSR0000SA0E
# 28   SA0E    Energy                      CUSR0000SA0E
# 29   SA0E    Energy                      CUSR0000SA0E
# 30   SA0E    Energy                      CUSR0000SA0E
# ⋮    ⋮       ⋮                           ⋮
# 6361 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6362 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6363 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6364 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6365 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6366 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6367 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6368 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6369 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6370 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6371 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6372 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6373 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6374 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6375 SS47015 Gasoline, unleaded midgrade CWSR0000SS47015
# 6376 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6377 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6378 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6379 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6380 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6381 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6382 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6383 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6384 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6385 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6386 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6387 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6388 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6389 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
# 6390 SS47016 Gasoline, unleaded premium  CWSR0000SS47016
#      DATA_TYPE                 YEAR JAN     FEB     MAR     APR     MAY
# 1    SEASONALLY ADJUSTED INDEX 2019 252.561 253.319 254.277 255.233 255.296
# 2    SEASONALLY ADJUSTED INDEX 2020 258.906 259.246 258.150 256.126 255.848
# 3    SEASONALLY ADJUSTED INDEX 2021 262.518 263.583 264.910 266.752 268.452
# 4    SEASONALLY ADJUSTED INDEX 2022 282.390 284.535 287.553 288.764 291.359
# 5    SEASONALLY ADJUSTED INDEX 2023 300.356 301.509 301.744 303.032 303.365
# 6    SEASONAL FACTOR           2019  99.664  99.786  99.971 100.123 100.312
# 7    SEASONAL FACTOR           2020  99.639  99.781  99.986 100.103 100.213
# 8    SEASONAL FACTOR           2021  99.643  99.784  99.988 100.113 100.277
⋮       ⋮       ⋮       ⋮       ⋮       ⋮       ⋮
# 6361 252.464 254.559 249.121 248.380 253.918 258.763 264.866
# 6362 199.844 208.957 212.703 214.826 213.855 215.315 230.504
# 6363 280.144 286.379 293.043 295.373 306.531 324.405 334.524
# 6364 437.433 406.790 366.246 349.837 361.833 359.826 335.822
# 6365 331.247 331.123 354.505 361.980 349.643 336.109 334.525
# 6366 103.672 103.458 101.794 101.756 101.086  98.344  94.370
# 6367 103.823 103.623 102.124 101.878 101.130  98.207  94.112
# 6368 103.792 104.022 102.485 101.961 101.174  98.209  93.712
# 6369 103.883 104.440 102.772 101.979 101.142  98.078  93.461
# 6370 104.021 104.769 103.068 102.065 101.087  97.854  93.205
# 6371 261.734 263.361 253.591 252.741 256.675 254.477 249.953
# 6372 207.485 216.528 217.221 218.860 216.272 211.455 216.931
# 6373 290.767 297.898 300.324 301.167 310.131 318.596 313.491
# 6374 454.418 424.853 376.398 356.759 365.965 352.911 313.864
# 6375 344.565 346.916 365.383 369.454 353.445 328.897 311.793
# 6376 248.793 249.603 245.083 245.120 250.831 255.827 260.526
# 6377 199.689 208.549 212.104 214.096 211.991 214.329 227.481
# 6378 273.434 279.935 285.998 288.557 296.181 313.319 323.807
# 6379 414.827 390.382 355.203 344.683 358.357 352.684 329.502
# 6380 324.738 325.269 345.034 355.261 344.347 331.866 330.808
# 6381 103.478 103.179 101.762 101.538 101.475  98.743  94.769
# 6382 103.607 103.343 102.066 101.688 101.524  98.584  94.472
# 6383 103.568 103.665 102.433 101.742 101.563  98.523  94.136
# 6384 103.611 103.980 102.720 101.795 101.584  98.408  93.858
# 6385 103.729 104.223 102.964 101.892 101.587  98.262  93.596
# 6386 257.445 257.537 249.403 248.891 254.532 252.612 246.899
# 6387 206.891 215.522 216.486 217.709 215.223 211.294 214.906
# 6388 283.190 290.195 292.956 293.583 300.811 308.691 304.819
# 6389 429.805 405.921 364.863 350.869 364.034 347.068 309.265
# 6390 336.849 339.006 355.260 361.983 349.810 326.097 309.625

# %% [markdown]
# We want to plot the average `SEASONALLY_ADJUSTED_INDEX` for `Energy`, `Food`, `Shelter`, and `Used cars and trucks` per month for over the period covered in the dataset (2019-2023).

# %% [markdown]
# Execute this cell. You'll need this months vector for the picot operation below:

# %%
months = c('JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC')

# %% [markdown]
# Here are the operations you'll need to perform:
# - filter for...
#   - `TITLE %in% c('Energy', 'Food', 'Shelter', 'Used cars and trucks')`
#   - and, `DATA_TYPE == 'SEASONALLY ADJUSTED INDEX'`
# - Pivot the columns for the Months so the table is in long-form and each row represents a month (hint: use `cols = months` with `pivot_longer`)
# - Create a column for the date with this mutate operation: `mutate(date_str = glue::glue('{YEAR}-{name}-01') |> str_to_lower(), date = as.Date(date_str, format = '%Y-%b-%d'))`
# - Group by `date` and `summarize` by taking the mean value for each date group.

# %%
price_index = 
df_price_index |> filter(TITLE %in% c('Energy', 'Food', 'Shelter', 'Used cars and trucks')) |> 
filter(DATA_TYPE == 'SEASONALLY ADJUSTED INDEX') |> 
pivot_longer(cols=months) |>
mutate(date_str=glue::glue('{YEAR}-{name}-01') |> 
       str_to_lower(), date=as.Date(date_str, format='%Y-%b-%d')) |> 
group_by(date, TITLE) |>
summarize(mean_value = mean(value, na.rm=TRUE))  
price_index
# Out:
# `summarise()` has grouped output by 'date'. You can override using the
# `.groups` argument.
#     date       TITLE                mean_value
# 1   2019-01-01 Energy               203.6260
# 2   2019-01-01 Food                 255.8640
# 3   2019-01-01 Shelter              309.3705
# 4   2019-01-01 Used cars and trucks 142.6770
# 5   2019-02-01 Energy               207.6265
# 6   2019-02-01 Food                 256.5735
# 7   2019-02-01 Shelter              310.4100
# 8   2019-02-01 Used cars and trucks 142.7450
# 9   2019-03-01 Energy               214.6510
# 10  2019-03-01 Food                 257.0070
# 11  2019-03-01 Shelter              311.4165
# 12  2019-03-01 Used cars and trucks 141.6930
# 13  2019-04-01 Energy               222.3670
# 14  2019-04-01 Food                 256.6345
# 15  2019-04-01 Shelter              312.5400
# 16  2019-04-01 Used cars and trucks 140.3830
# 17  2019-05-01 Energy               220.4325
# 18  2019-05-01 Food                 257.0960
# 19  2019-05-01 Shelter              313.3775
# 20  2019-05-01 Used cars and trucks 139.0690
# 21  2019-06-01 Energy               214.6285
# 22  2019-06-01 Food                 257.2045
# 23  2019-06-01 Shelter              314.3205
# 24  2019-06-01 Used cars and trucks 138.7235
# 25  2019-07-01 Energy               216.4905
# 26  2019-07-01 Food                 257.3170
# 27  2019-07-01 Shelter              315.1605
# 28  2019-07-01 Used cars and trucks 138.5965
# 29  2019-08-01 Energy               213.5475
# 30  2019-08-01 Food                 257.5355
# ⋮   ⋮          ⋮                    ⋮
# 211 2023-05-01 Shelter              374.6015
# 212 2023-05-01 Used cars and trucks 199.4795
# 213 2023-06-01 Energy               276.1090
# 214 2023-06-01 Food                 321.6735
# 215 2023-06-01 Shelter              376.1965
# 216 2023-06-01 Used cars and trucks 198.2840
# 217 2023-07-01 Energy               276.0010
# 218 2023-07-01 Food                 322.2915
# 219 2023-07-01 Shelter              377.9395
# 220 2023-07-01 Used cars and trucks 195.3875
# 221 2023-08-01 Energy               288.4450
# 222 2023-08-01 Food                 323.0800
# 223 2023-08-01 Shelter              379.2675
# 224 2023-08-01 Used cars and trucks 191.7485
# 225 2023-09-01 Energy               291.8655
# 226 2023-09-01 Food                 323.6800
# 227 2023-09-01 Shelter              381.4805
# 228 2023-09-01 Used cars and trucks 188.3105
# 229 2023-10-01 Energy               285.3150
# 230 2023-10-01 Food                 324.6440
# 231 2023-10-01 Shelter              382.8515
# 232 2023-10-01 Used cars and trucks 187.5510
# 233 2023-11-01 Energy               280.6215
# 234 2023-11-01 Food                 325.2115
# 235 2023-11-01 Shelter              384.5535
# 236 2023-11-01 Used cars and trucks 190.1300
# 237 2023-12-01 Energy               280.1400
# 238 2023-12-01 Food                 325.9040
# 239 2023-12-01 Shelter              386.1795
# 240 2023-12-01 Used cars and trucks 191.2400

# %% [markdown]
# The first three rows of your table will look something like this:
#
# ![image.png](attachment:c709ee7c-744d-4ed9-81ce-7a8e574dda03.png)

# %%
options(repr.plot.width = 8, repr.plot.height = 4)

ggplot(price_index, aes(y=mean_value, x=date, color=TITLE)) + 
geom_point(size = 0.8) + 
geom_line(size = 0.8) + 
theme_minimal() + 
labs(title = "Average Change in CPI Over Time by Consumption Type", 
    x = 'Date', 
    y = 'Consumer Price Index (CPI)', 
   color = "Consumption Type") + 
scale_color_brewer(palette = 'Set2')
# Out:
# plot without title

# %% [markdown]
# Ok! Now make this plot:
#
# ![image.png](attachment:2f4b62ed-4b42-4eec-b2a7-ba9ac3c6df1a.png)

# %% [markdown]
# This is how the [USBLS defines the index](https://www.bls.gov/cpi/) (if you're curious):
#
# >  The Consumer Price Index (CPI) is a measure of the average change over time in the prices paid by urban consumers for a market basket of consumer goods and services.
